# %%
import csv
import random

# %matplotlib inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 20000
List = [['R', 'G', 'B', 'Type']]
for n in range(0, N):
    R = random.randint(0, 255)
    G = random.randint(0, 255)
    B = random.randint(0, 255)
    if R >= 128 or G >= 128 or B >= 128:
        Type = 1
    else:
        Type = 0
    List.append([R, G, B, Type])

# %%
with open('dataset1.csv', 'w', encoding="utf8", newline='') as f:
    writer = csv.writer(f)
    for row in List:
        writer.writerow(row)

# %%
data = pd.read_csv('dataset1.csv')

X = data.iloc[:,:3].values
y = data.iloc[:,3].values

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X[y == 1, 0], X[y == 1, 1], X[y == 1, 2], c='gray', label='Яркий')
ax.scatter(X[y == 0, 0], X[y == 0, 1], X[y == 0, 2], c='black', label='Тусклый')
